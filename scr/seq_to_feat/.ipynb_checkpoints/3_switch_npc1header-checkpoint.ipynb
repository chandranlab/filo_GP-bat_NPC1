# %%
import pandas as pd
import os
import re

# %%
# user options
switch_mode = 2 # either 1, 2
cutoff = 1000
# switch_mode 1: convert specie name to Bx
# swith_mode 2: convert specie name to Bx|specie name
rootdir = '/Users/gorkalasso/Documents/GitHub/filo_GP-bat_NPC1/scr/seq_to_feat/'
infile = rootdir + 'output/2_interface_2_fasta/' +  str(cutoff) + '/interface_host_' + str(cutoff) + '.txt'
# infile = rootdir + str(cutoff) + '/interface_host_' + str(cutoff) + '_nr100'
# infile = rootdir + str(cutoff) + '/interface_host_' + str(cutoff) + '_nr100.clstr'
# infile = '/Users/gorkalasso/Dropbox (EinsteinMed)/ebola/NPC1_GP1_binding_determinants/1_NPC1_seqs/4_ali_on_5f1bC_1.fasta'

# %%
# setting output file
filename, ext = os.path.splitext(infile)
# print(filename, ext)
tag = ''
if switch_mode == 1:
    tag = 'Bx'
elif switch_mode == 2:
    tag = 'Bx_sp'
outfile = filename + '_' + tag + ext
print(outfile)
# Out:
# /Users/gorkalasso/Dropbox (EinsteinMed)/ebola/NPC1_GP1_binding_determinants/2_NPC1_interfacial/1000/interface_host_1000_nr100_Bx_sp.clstr

# %%
# load NPC1 Mapping table
mapfile = '/Users/gorkalasso/Dropbox (EinsteinMed)/ebola/NPC1_GP1_binding_determinants/0_dataset/npc1_list.xlsx'
sheetnm = 'in_project'
df = pd.read_excel(mapfile, sheet_name = sheetnm)
# display(df)

# %%
infl = open(infile, 'r')
outfl = open(outfile,'w')

# %%
# get format of input
fmt = 'fasta'
for ln in infl:
    ln = ln.rstrip()
    if len(ln) > 8 and ln[0:8] == '>Cluster':
        fmt = 'cluster'
print('Input format is', fmt)
# Out:
# Input format is cluster

# %%
infl.seek(0)
if fmt == 'cluster':
    for ln in infl:
        ln = ln.rstrip()
        print(ln)
        if '>Cluster' in ln:
            print(ln, file=outfl)
        else:
            t1, t2 = ln.split('>')
            sp,t3 = t2.split('...')
            sp = re.sub('\s','',sp)
            sp = re.sub('\_',' ',sp)
            sp = re.sub('sp$','sp.',sp)
            bx = ''
            print('#' + sp + '#')
            if df['Species'].str.contains(sp).any():
#                 print('\t', 'found!!')
                idx = df.index[df['Species'] == sp].tolist()[0]
                bx = df.at[idx,'Label']
            elif sp == 'NPC1 human':
                bx = 'DC52'
            else:
                print('Fatal error, couldnt find BX for', sp)
                quit()
            if switch_mode == 1:
                newnm = bx
            elif switch_mode == 2:
                newnm = bx + '|' + sp
            print(t1 + '>' + newnm + '...' + t3, file=outfl)
elif fmt == 'fasta':
    for ln in infl:
        ln = ln.rstrip()
        print(ln)
        if ln[0:1] != '>':
            print(ln, file=outfl)
        else:
            sp = ln[1:]
            sp = re.sub('\s','',sp)
            sp = re.sub('\_',' ',sp)
            sp = re.sub('sp$','sp.',sp)
            bx = ''
            print('#' + sp + '#')
            if df['Species'].str.contains(sp).any():
#                 print('\t', 'found!!')
                idx = df.index[df['Species'] == sp].tolist()[0]
                bx = df.at[idx,'Label']
            elif sp == 'NPC1 human':
                bx = 'DC52'
            else:
                print('Fatal error, couldnt find BX for', sp)
                quit()
            if switch_mode == 1:
                newnm = bx
            elif switch_mode == 2:
                newnm = bx + '|' + sp
            print('>' + newnm, file=outfl)
# Out:
# >Cluster 0
# 0	215aa, > NPC1_human... *
# #NPC1 human#
# >Cluster 1
# 0	215aa, > Nycteris_hispida... *
# #Nycteris hispida#
# >Cluster 2
# 0	215aa, > Rhinopoma_microphyllum... *
# #Rhinopoma microphyllum#
# >Cluster 3
# 0	215aa, > Pteronotus_quadridens... *
# #Pteronotus quadridens#
# >Cluster 4
# 0	215aa, > Cynopterus_sphinx... *
# #Cynopterus sphinx#
# >Cluster 5
# 0	215aa, > Coleura_afra... *
# #Coleura afra#
# >Cluster 6
# 0	215aa, > Diaemus_youngi... *
# #Diaemus youngi#
# >Cluster 7
# 0	215aa, > Hipposideros_armiger... *
# #Hipposideros armiger#
# >Cluster 8
# 0	215aa, > Desmodus_rotundus... *
# #Desmodus rotundus#
# >Cluster 9
# 0	215aa, > Triaenops_persicus... *
# #Triaenops persicus#
# >Cluster 10
# 0	215aa, > Miniopterus_inflatus... *
# #Miniopterus inflatus#
# >Cluster 11
# 0	215aa, > Hipposideros_jonesi... *
# #Hipposideros jonesi#
# >Cluster 12
# 0	215aa, > Brachyphylla_cavernarum... *
# #Brachyphylla cavernarum#
# >Cluster 13
# 0	215aa, > Myonycteris_angolensis... *
# #Myonycteris angolensis#
# >Cluster 14
# 0	215aa, > Pteronotus_parnellii... *
# #Pteronotus parnellii#
# >Cluster 15
# 0	215aa, > Natalus_stramineus... *
# #Natalus stramineus#
# >Cluster 16
# 0	215aa, > Hipposideros_ruber... *
# #Hipposideros ruber#
# >Cluster 17
# 0	215aa, > Vampyressa_bidens... *
# #Vampyressa bidens#
# >Cluster 18
# 0	215aa, > Rhinolophus_shortridgei... *
# #Rhinolophus shortridgei#
# >Cluster 19
# 0	215aa, > Balantiopteryx_plicata... *
# #Balantiopteryx plicata#
# >Cluster 20
# 0	215aa, > Hipposideros_larvatus... *
# #Hipposideros larvatus#
# >Cluster 21
# 0	215aa, > Mormoops_megalophylla... *
# #Mormoops megalophylla#
# >Cluster 22
# 0	215aa, > Monophyllus_redmani... *
# #Monophyllus redmani#
# >Cluster 23
# 0	215aa, > Epomophorus_labiatus... *
# #Epomophorus labiatus#
# >Cluster 24
# 0	215aa, > Glossophaga_sp.... *
# #Glossophaga sp.#
# >Cluster 25
# 0	215aa, > Macrotus_waterhousii... *
# #Macrotus waterhousii#
# >Cluster 26
# 0	215aa, > Neoromicia_nanus... *
# #Neoromicia nanus#
# >Cluster 27
# 0	215aa, > Mormoops_blainvillii... *
# #Mormoops blainvillii#
# >Cluster 28
# 0	215aa, > Molossus_rufus... *
# #Molossus rufus#
# >Cluster 29
# 0	215aa, > Hypsignathus_monstrosus... *
# #Hypsignathus monstrosus#
# >Cluster 30
# 0	215aa, > Micropteropus_pusillus... *
# #Micropteropus pusillus#
# >Cluster 31
# 0	215aa, > Epomops_buettikoferi... *
# #Epomops buettikoferi#
# >Cluster 32
# 0	215aa, > Erophylla_sezekorni... *
# #Erophylla sezekorni#
# >Cluster 33
# 0	215aa, > Taphozous_longimanes... *
# #Taphozous longimanes#
# >Cluster 34
# 0	215aa, > Myotis_davidii... *
# #Myotis davidii#
# >Cluster 35
# 0	215aa, > Rhinolophus_hipposideros... *
# #Rhinolophus hipposideros#
# >Cluster 36
# 0	215aa, > Rhinolophus_landeri... *
# #Rhinolophus landeri#
# >Cluster 37
# 0	215aa, > Myotis_brandtii... *
# #Myotis brandtii#
# >Cluster 38
# 0	215aa, > Rhinolophus_fumigatus... *
# #Rhinolophus fumigatus#
# >Cluster 39
# 0	215aa, > Rhinolophus_sinicus... *
# #Rhinolophus sinicus#
# >Cluster 40
# 0	215aa, > Eidolon_helvum... *
# #Eidolon helvum#
# >Cluster 41
# 0	215aa, > Rhinolophus_clivosus... *
# #Rhinolophus clivosus#
# >Cluster 42
# 0	215aa, > Rousettus_leschenaultii... *
# #Rousettus leschenaultii#
# >Cluster 43
# 0	215aa, > Triaenops_afer... *
# #Triaenops afer#
# >Cluster 44
# 0	215aa, > Myotis_bocagii... *
# #Myotis bocagii#
# >Cluster 45
# 0	215aa, > Carollia_sowelli... *
# #Carollia sowelli#
# >Cluster 46
# 0	215aa, > Artibeus_concolor... *
# #Artibeus concolor#
# >Cluster 47
# 0	215aa, > Artibeus_glaucus... *
# #Artibeus glaucus#
# >Cluster 48
# 0	215aa, > Glauconycteris_poensis... *
# #Glauconycteris poensis#
# >Cluster 49
# 0	215aa, > Uroderma_bilobatum... *
# #Uroderma bilobatum#
# >Cluster 50
# 0	215aa, > Artibeus_jamaicensis... *
# #Artibeus jamaicensis#
# >Cluster 51
# 0	215aa, > Carollia_brevicauda... *
# #Carollia brevicauda#
# >Cluster 52
# 0	215aa, > Pteropus_medius... *
# #Pteropus medius#
# >Cluster 53
# 0	215aa, > Myotis_lucifugus... *
# #Myotis lucifugus#
# >Cluster 54
# 0	215aa, > Mimon_crenulatum... *
# #Mimon crenulatum#
# >Cluster 55
# 0	215aa, > Artibeus_lituratus... *
# #Artibeus lituratus#
# >Cluster 56
# 0	215aa, > Neoromicia_rendalli... *
# #Neoromicia rendalli#
# >Cluster 57
# 0	215aa, > Rhinophylla_pumilio... *
# #Rhinophylla pumilio#
# >Cluster 58
# 0	215aa, > Molossops_temminckii... *
# #Molossops temminckii#
# >Cluster 59
# 0	215aa, > Phyllostomus_hastatus_... *
# #Phyllostomus hastatus #
# >Cluster 60
# 0	215aa, > Pipistrellus_nanulus... *
# #Pipistrellus nanulus#
# >Cluster 61
# 0	215aa, > Pteropus_alecto... *
# #Pteropus alecto#
# >Cluster 62
# 0	215aa, > Phylloderma_stenops... *
# #Phylloderma stenops#
# >Cluster 63
# 0	215aa, > Sturnira_luisi... *
# #Sturnira luisi#
# >Cluster 64
# 0	215aa, > Pipistrellus_sp.... *
# #Pipistrellus sp.#
# >Cluster 65
# 0	215aa, > Carollia_perspicillata... *
# #Carollia perspicillata#
# >Cluster 66
# 0	215aa, > Saccopteryx_bilineata... *
# #Saccopteryx bilineata#
# >Cluster 67
# 0	215aa, > Unidentified_Vespertilionidae... *
# #Unidentified Vespertilionidae#
# >Cluster 68
# 0	215aa, > Sturnira_lilium... *
# #Sturnira lilium#
# >Cluster 69
# 0	215aa, > Phyllostomus_elongatus... *
# #Phyllostomus elongatus#
# >Cluster 70
# 0	215aa, > Scotophilus_viridis_nigritellus... *
# #Scotophilus viridis nigritellus#
# >Cluster 71
# 0	215aa, > Nyctinomops_macrotis... *
# #Nyctinomops macrotis#
# >Cluster 72
# 0	215aa, > Anoura_geoffroyi... *
# #Anoura geoffroyi#
# >Cluster 73
# 0	215aa, > Ametrida_centurio... *
# #Ametrida centurio#
# >Cluster 74
# 0	215aa, > Centurio_senex... *
# #Centurio senex#
# >Cluster 75
# 0	215aa, > Mops_condylurus... *
# #Mops condylurus#
# >Cluster 76
# 0	215aa, > Glossophaga_soricina... *
# #Glossophaga soricina#
# >Cluster 77
# 0	215aa, > Glossophaga_leachii... *
# #Glossophaga leachii#
# >Cluster 78
# 0	215aa, > Chaerephon_atsinanana_... *
# #Chaerephon atsinanana #
# >Cluster 79
# 0	215aa, > Chaerephon_leucogaster... *
# #Chaerephon leucogaster#
# >Cluster 80
# 0	215aa, > Stenoderma_rufum... *
# #Stenoderma rufum#
# >Cluster 81
# 0	215aa, > Chaerephon_pumilus... *
# #Chaerephon pumilus#
# >Cluster 82
# 0	215aa, > Pipistrellus_tenuis... *
# #Pipistrellus tenuis#

# %%
outfl.close()
infl.close()

# %%
print('Finito')
# Out:
# Finito
