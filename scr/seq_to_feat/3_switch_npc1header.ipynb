# %%
import pandas as pd
import os
import re

# %%
# user options
switch_mode = 1 # either 1, 2
cutoff = 7
# switch_mode 1: convert specie name to Bx
# swith_mode 2: convert specie name to Bx|specie name
rootdir = '/Users/gorkalasso/Documents/GitHub/filo_GP-bat_NPC1/scr/seq_to_feat/'
infile = rootdir + 'output/2_interface_2_fasta/' +  str(cutoff) + '/interface_host_' + str(cutoff) + '.txt'
# infile = rootdir + str(cutoff) + '/interface_host_' + str(cutoff) + '_nr100'
# infile = rootdir + str(cutoff) + '/interface_host_' + str(cutoff) + '_nr100.clstr'
# infile = '/Users/gorkalasso/Dropbox (EinsteinMed)/ebola/NPC1_GP1_binding_determinants/1_NPC1_seqs/4_ali_on_5f1bC_1.fasta'

# %%
# setting output file
filename, ext = os.path.splitext(infile)
# print(filename, ext)
tag = ''
if switch_mode == 1:
    tag = 'Bx'
elif switch_mode == 2:
    tag = 'Bx_sp'
outfile = filename + '_' + tag + ext
print(outfile)
# Out:
# /Users/gorkalasso/Documents/GitHub/filo_GP-bat_NPC1/scr/seq_to_feat/output/2_interface_2_fasta/7/interface_host_7_Bx.txt

# %%
# load NPC1 Mapping table
mapfile = rootdir + 'input/0_npc1_list.xlsx'
sheetnm = 'in_project'
df = pd.read_excel(mapfile, sheet_name = sheetnm)
# display(df)

# %%
infl = open(infile, 'r')
outfl = open(outfile,'w')

# %%
# get format of input
fmt = 'fasta'
for ln in infl:
    ln = ln.rstrip()
    if len(ln) > 8 and ln[0:8] == '>Cluster':
        fmt = 'cluster'
print('Input format is', fmt)
# Out:
# Input format is fasta

# %%
infl.seek(0)
if fmt == 'cluster':
    for ln in infl:
        ln = ln.rstrip()
        print(ln)
        if '>Cluster' in ln:
            print(ln, file=outfl)
        else:
            t1, t2 = ln.split('>')
            sp,t3 = t2.split('...')
            sp = re.sub('\s','',sp)
            sp = re.sub('\_',' ',sp)
            sp = re.sub('sp$','sp.',sp)
            bx = ''
            print('#' + sp + '#')
            if df['Species'].str.contains(sp).any():
#                 print('\t', 'found!!')
                idx = df.index[df['Species'] == sp].tolist()[0]
                bx = df.at[idx,'Label']
            elif sp == 'NPC1 human':
                bx = 'DC52'
            else:
                print('Fatal error, couldnt find BX for', sp)
                quit()
            if switch_mode == 1:
                newnm = bx
            elif switch_mode == 2:
                newnm = bx + '|' + sp
            print(t1 + '>' + newnm + '...' + t3, file=outfl)
elif fmt == 'fasta':
    for ln in infl:
        ln = ln.rstrip()
        print(ln)
        if ln[0:1] != '>':
            print(ln, file=outfl)
        else:
            sp = ln[1:]
            sp = re.sub('\s','',sp)
            sp = re.sub('\_',' ',sp)
            sp = re.sub('sp$','sp.',sp)
            bx = ''
            print('#' + sp + '#')
            if df['Species'].str.contains(sp).any():
#                 print('\t', 'found!!')
                idx = df.index[df['Species'] == sp].tolist()[0]
                bx = df.at[idx,'Label']
            elif sp == 'NPC1 human':
                bx = 'DC52'
            else:
                print('Fatal error, couldnt find BX for', sp)
                quit()
            if switch_mode == 1:
                newnm = bx
            elif switch_mode == 2:
                newnm = bx + '|' + sp
            print('>' + newnm, file=outfl)
# Out:
# >NPC1_human
# #NPC1 human#
# IYQPYPSGADKKGDDFFVYDL
# >Nycteris_hispida
# #Nycteris hispida#
# IYQPYPSGSDKIGDDFFVYDV
# >Rhinopoma_microphyllum
# #Rhinopoma microphyllum#
# IYQPYPSGSDKIGDDFFVYDV
# >Pteronotus_quadridens
# #Pteronotus quadridens#
# IYQPYPSGSDKVGDYFFVYDV
# >Cynopterus_sphinx
# #Cynopterus sphinx#
# TYQPYPAGSDKIGDDFFVYDL
# >Coleura_afra
# #Coleura afra#
# TYEPYPSGSSKVGDDFYVYDL
# >Diaemus_youngi
# #Diaemus youngi#
# TYQPYPSGSDKIGDPFYVYDV
# >Hipposideros_armiger
# #Hipposideros armiger#
# TYQPYPAGSDTIGDDFYVYDL
# >Desmodus_rotundus
# #Desmodus rotundus#
# TYQPYPSGSDKIGDAFYVYDV
# >Triaenops_persicus
# #Triaenops persicus#
# TYQPYPAGSDKIGDDFYVYDL
# >Miniopterus_inflatus
# #Miniopterus inflatus#
# TYEPYPSGSDKIGDDFYVYDL
# >Hipposideros_jonesi
# #Hipposideros jonesi#
# TYQPYPAGSDEIGDDFYVYDL
# >Brachyphylla_cavernarum
# #Brachyphylla cavernarum#
# TYQPYPSGSDKIGDPFYVYDV
# >Myonycteris_angolensis
# #Myonycteris angolensis#
# TYQPYPAGSDKIGDDFFVYDL
# >Pteronotus_parnellii
# #Pteronotus parnellii#
# IYKPYPSGSDKVGDYFYVYDV
# >Natalus_stramineus
# #Natalus stramineus#
# TYQPYPSGSDKIGDDFFVYDM
# >Hipposideros_ruber
# #Hipposideros ruber#
# TYQPYPAGSDKIGDDFYVYDL
# >Vampyressa_bidens
# #Vampyressa bidens#
# IYQPYPSGSDKIGDPFYVYDV
# >Rhinolophus_shortridgei
# #Rhinolophus shortridgei#
# TYEPYPSGSDKVGDDFYVYDL
# >Balantiopteryx_plicata
# #Balantiopteryx plicata#
# TYEPYPSGSDKVGDDFYVYDL
# >Hipposideros_larvatus
# #Hipposideros larvatus#
# TYQPYPTGSDTIGDDFYVYDL
# >Mormoops_megalophylla
# #Mormoops megalophylla#
# TYSPYPSGSDKVGDDFYVYDM
# >Monophyllus_redmani
# #Monophyllus redmani#
# TYQPYPSGSDKIGDPFYVYDV
# >Epomophorus_labiatus
# #Epomophorus labiatus#
# TYQPYPAGSDKIGDDFFVYDL
# >Glossophaga_sp.
# #Glossophaga sp.#
# TYQPYPSGSDKIGDAFYVYDV
# >Macrotus_waterhousii
# #Macrotus waterhousii#
# TYQPYPSGSDKIGDPFYVYDV
# >Neoromicia_nanus
# #Neoromicia nanus#
# TYQPYPSGSDEIGDDFYTYDL
# >Mormoops_blainvillii
# #Mormoops blainvillii#
# TYSPYPSGSDKVGDDFFVYDM
# >Molossus_rufus
# #Molossus rufus#
# IYHPYPSGSDEIGDDFFVYDL
# >Hypsignathus_monstrosus
# #Hypsignathus monstrosus#
# TYQPYPAGSDKIGDDFFVYDL
# >Micropteropus_pusillus
# #Micropteropus pusillus#
# TYQPYPAGSDKIGDDFFVYDL
# >Epomops_buettikoferi
# #Epomops buettikoferi#
# TYQPYPAGSDKIGDDFFVYDL
# >Erophylla_sezekorni
# #Erophylla sezekorni#
# TYQPYPSGSDKIGDPFYVYDV
# >Taphozous_longimanes
# #Taphozous longimanes#
# TYEPYPSGSDKVGDDFYVYDL
# >Myotis_davidii
# #Myotis davidii#
# TYEPYPSGSDEIGDDFFIYDL
# >Rhinolophus_hipposideros
# #Rhinolophus hipposideros#
# KYEPYPTGSDKIGDDFYVYDL
# >Rhinolophus_landeri
# #Rhinolophus landeri#
# KYEPYPTGSDKIGDDFYVYDL
# >Myotis_brandtii
# #Myotis brandtii#
# TYEPYPSGSDEIGDDFYTYDL
# >Rhinolophus_fumigatus
# #Rhinolophus fumigatus#
# KYEPYPSGSDKIGDDFYVYDL
# >Rhinolophus_sinicus
# #Rhinolophus sinicus#
# KYEPYPTGSDKIGDDFYVYDL
# >Eidolon_helvum
# #Eidolon helvum#
# TYQPYPAGSDKIGDFFFTYDL
# >Rhinolophus_clivosus
# #Rhinolophus clivosus#
# KYEPYPSGSDKIGDDFYVYDS
# >Rousettus_leschenaultii
# #Rousettus leschenaultii#
# TYQPYPAGSDKIGDDFFVYDL
# >Triaenops_afer
# #Triaenops afer#
# TYQPYPAGSDKIEDDFYIYDV
# >Myotis_bocagii
# #Myotis bocagii#
# TYEPYPSGSDEIGDDFYTYDL
# >Carollia_sowelli
# #Carollia sowelli#
# TYQPYPSGSDTIGDPFYVYDV
# >Artibeus_concolor
# #Artibeus concolor#
# TYQPYPSGSDKIGDPFYVYDV
# >Artibeus_glaucus
# #Artibeus glaucus#
# TYQPYPSGSDKIGDPFYVYDV
# >Glauconycteris_poensis
# #Glauconycteris poensis#
# TYEPYPSGSDAIGDDFYIYDL
# >Uroderma_bilobatum
# #Uroderma bilobatum#
# TYQPYPSGSDQIGDHFYVYDV
# >Artibeus_jamaicensis
# #Artibeus jamaicensis#
# TYQPYPSGSDKIGDPFYVYDV
# >Carollia_brevicauda
# #Carollia brevicauda#
# TYQPYPSGSDTIGDPFYVYDV
# >Pteropus_medius
# #Pteropus medius#
# TYQPYPTETDKIGDDFYVYDL
# >Myotis_lucifugus
# #Myotis lucifugus#
# TYEPYPSGSDEIGDDFYTYDL
# >Mimon_crenulatum
# #Mimon crenulatum#
# TYQPYPSGSDQIGDPFYVYDV
# >Artibeus_lituratus
# #Artibeus lituratus#
# TYQPYPSGSDKIGDPFYVYDV
# >Neoromicia_rendalli
# #Neoromicia rendalli#
# TYEPYPSGSDEIGDDFYTYDM
# >Rhinophylla_pumilio
# #Rhinophylla pumilio#
# TYQPYPSGSDKIGDPFYVYDV
# >Molossops_temminckii
# #Molossops temminckii#
# TYHPYPSGSDEVGDDFFVYDM
# >Phyllostomus_hastatus_
# #Phyllostomus hastatus #
# TYQPYPSGSDKIGDPFYTYDV
# >Pipistrellus_nanulus
# #Pipistrellus nanulus#
# TYEPYPSGSDEIGDDFYTYDL
# >Pteropus_alecto
# #Pteropus alecto#
# TYQPYPTETDKIGDDFYVYDL
# >Phylloderma_stenops
# #Phylloderma stenops#
# TYQPYPFGSDKIGDPFYTYDV
# >Sturnira_luisi
# #Sturnira luisi#
# TYQPYPSGSDKVGDPFYVYDV
# >Pipistrellus_sp.
# #Pipistrellus sp.#
# TYQPYPSGSDEVGDDFYTYDL
# >Carollia_perspicillata
# #Carollia perspicillata#
# TYQPYPSGSDTIGDPFYVYDV
# >Saccopteryx_bilineata
# #Saccopteryx bilineata#
# TYEPYPSGSNKVGDDFFVYDL
# >Unidentified_Vespertilionidae
# #Unidentified Vespertilionidae#
# TYEPYPSGSDEIGDDFFTYDL
# >Sturnira_lilium
# #Sturnira lilium#
# TYQPYPSGSDKVGDPFYVYDV
# >Phyllostomus_elongatus
# #Phyllostomus elongatus#
# TYQPYPSGSDQIGDPFYTYDV
# >Scotophilus_viridis_nigritellus
# #Scotophilus viridis nigritellus#
# TYQPYPSGSDAIGDDFYTYDL
# >Nyctinomops_macrotis
# #Nyctinomops macrotis#
# TYHPYPSGSDEIGDDFFVYDM
# >Anoura_geoffroyi
# #Anoura geoffroyi#
# TYEPYPSGSDKIGDHFYVYDV
# >Ametrida_centurio
# #Ametrida centurio#
# TYQPYPSGSDKIGDPFYVYDV
# >Centurio_senex
# #Centurio senex#
# TYQPYPSGSDKIGDPFYVYDV
# >Mops_condylurus
# #Mops condylurus#
# TYHPYPSGSDQVGDDFFVYDM
# >Glossophaga_soricina
# #Glossophaga soricina#
# TYQPYPSGSNKIGDPFYVYDV
# >Glossophaga_leachii
# #Glossophaga leachii#
# TYQPYPSGSNTIGDPFYVYDV
# >Chaerephon_atsinanana_
# #Chaerephon atsinanana #
# TYHPYPSGSDQIGDDFFVYDM
# >Chaerephon_leucogaster
# #Chaerephon leucogaster#
# TYSPYPSGSDQIGDGFFVYDM
# >Stenoderma_rufum
# #Stenoderma rufum#
# TYQPYPSGSDKIGDPFYVYDV
# >Chaerephon_pumilus
# #Chaerephon pumilus#
# TYSPYPSGSDQIGDGFFVYDM
# >Pipistrellus_tenuis
# #Pipistrellus tenuis#
# TYEPYPSGSNWRGDFYYTYDL

# %%
outfl.close()
infl.close()

# %%
print('Finito')
# Out:
# Finito
